# %%
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
from PIL import Image

# %%
img = Image.open("/Users/arponbiswas/Computer-Vision-Projects/Image_classification_projects/PC_Parts_Image_Classification/Data/pc_parts_ready/motherboard/9.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
layer_1 = nn.Sequential(
    nn.Conv2d(in_channels=1, out_channels=1, kernel_size=6, stride=4, padding=0),
    nn.MaxPool2d(kernel_size=3, stride=3)
)
